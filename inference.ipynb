# %% [markdown]
# # STEP 1: Wget testing data and code

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
gdd.download_file_from_google_drive(file_id='1QGiVqKjPV7o-SL0LmTajEiJNMh_5Aj2E',
                  dest_path='./inference.zip',
                  unzip=True)
# %cd inference
# Out:
# ...
# Unzipping...Done.
# /content/inference

# %% [markdown]
# # STEP 2: Run inference

# %%
# !python test_IMDN.py --test_folder test_data --output_folder results --checkpoint best.pth --upscale_factor 3
# Out:
# Namespace(checkpoint='best.pth', cuda=True, is_y=True, output_folder='results', test_folder='test_data', upscale_factor=3)
# Save the result to results folder,
